# %%
import requests

request = requests.get("https://hoshitetsu-portfolio.com/")

print(request.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#     <!-- googlefont -->
#     <link rel="preconnect" href="https://fonts.googleapis.com">
#     <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
#     <link href="https://fonts.googleapis.com/css2?family=Inria+Serif:ital,wght@0,300;0,400;0,700;1,300;1,400;1,700&family=Noto+Serif+JP&display=swap" rel="stylesheet">
#
#     <!-- slickのCDN読み込み -->
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick-theme.min.css">
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/slick-carousel@1.8.1/slick/slick.min.css">
#
# 	<!-- ファビコン -->
# 	<link rel="icon" href="https://hoshitetsu-portfolio.com/wp-content/themes/hoshitetsu_portfolio/assets/img/favicon.ico">
#
#     <!-- style.css -->
# ...

# %%
import requests

request_blog = requests.get("https://hoshitetsu-portfolio.com/blog")

print(request_blog.text)
# Out:
# <!DOCTYPE html>
# <html class="pc" lang="ja">
# <head>
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width">
# <title>ほしてつのエンジニア日記</title>
# <meta name="description" content="アスペルガーもちエンジニアによるアウトプットブログ">
# <link rel="pingback" href="https://hoshitetsu-portfolio.com/blog/xmlrpc.php">
# <meta name='robots' content='max-image-preview:large' />
# <link rel="alternate" type="application/rss+xml" title="ほしてつのエンジニア日記 &raquo; フィード" href="https://hoshitetsu-portfolio.com/blog/feed/" />
# <link rel="alternate" type="application/rss+xml" title="ほしてつのエンジニア日記 &raquo; コメントフィード" href="https://hoshitetsu-portfolio.com/blog/comments/feed/" />
# <link rel='stylesheet' id='style-css' href='https://hoshitetsu-portfolio.com/blog/wp-content/themes/rebirth_free001/style.css?ver=1.3.1' type='text/css' media='all' />
# ...

# %%
import requests

hs_photo = requests.get("https://hoshitetsu-photo.com/")

print(hs_photo.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
#     <!-- Google Tag Manager -->
#     <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-T2JXVNV8');</script>
#     <!-- End Google Tag Manager -->
#
# 	<!-- Google tag (gtag.js) -->
# 	<script async src="https://www.googletagmanager.com/gtag/js?id=G-F96WTQT1G5"></script>
# 	<script>
# 	  window.dataLayer = window.dataLayer || [];
# 	  function gtag(){dataLayer.push(arguments);}
# 	  gtag('js', new Date());
#
# 	  gtag('config', 'G-F96WTQT1G5');
# 	</script>
#
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#     <!-- slickのCSS -->
# ...
